# %% [markdown]
# <a href="https://colab.research.google.com/github/eulerpereirabanhos/-ListaComFuncionalidadesBasicas/blob/main/Curso_B%C3%A1sico1_de_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Passo a Passo de solução do Desafio

# %%
# lógica de programação
# Passo 0 - Entender o desafio que voçê quer resolver
# Passo 1 - Percorrer todos os arquivos da pasta base de dados (Pasta Vendas)
import os
import pandas as pd
import plotly.express as px

lista_arquivo = os.listdir("/content/drive/MyDrive/Curso Básico1 de Python/Vendas")
display(lista_arquivo)
# Out:
# ['Devolucoes - Goiás.csv',
#  'Vendas - Porto Alegre.csv',
#  'Vendas - Goiás.csv',
#  'Vendas - Curitiba.csv',
#  'Vendas - São Paulo.csv',
#  'Vendas - Rio de Janeiro.csv',
#  'Devolucoes - Curitiba.csv',
#  'Vendas - Fortaleza.csv',
#  'Devolucoes - Recife.csv',
#  'Vendas - Salvador.csv',
#  'Devolucoes - Porto Alegre.csv',
#  'Vendas - Recife.csv',
#  'Vendas - Belo Horizonte.csv',
#  'Devolucoes - Salvador.csv',
#  'Devolucoes - Rio de Janeiro.csv',
#  'Devolucoes - Fortaleza.csv',
#  'Devolucoes - Belo Horizonte.csv',
#  'Devolucoes - São Paulo.csv']

# %%
tabela_total = pd.DataFrame()


# Passo 2 - Impotar as Bases de dados de vendas
for arquivo in lista_arquivo:
  # Se tem "vendas" no nome do arquivo, então
  if "Vendas" in arquivo:
    # Importar o arquivo
   tabela = pd.read_csv(f"/content/drive/MyDrive/Curso Básico1 de Python/Vendas/{arquivo}")
   tabela_total = pd.concat([tabela_total, tabela])

# passo 3 - Tratar / Compilar as bases de dados
display(tabela_total)
# Out:
#      Unnamed: 0     SKU    Produto  Quantidade Vendida Primeiro Nome  \
# 0            14  HL4379  Televisão                   4         Ylana
# 1            34  HL1148     Câmera                   1        Rubens
# 2            43  HL1148     Câmera                   5        Paloma
# 3            49  HL8851   Notebook                   5         Breno
# 4            52  HL4379  Televisão                   2        Lorena
# ..          ...     ...        ...                 ...           ...
# 644        9910  HL1148     Câmera                   4        Norman
# 645        9927  HL2714     Tablet                   2        Marina
# 646        9932  HL1918     iPhone                   1          José
# 647        9942  HL4379  Televisão                   1      Fernanda
# 648        9978  HL8851   Notebook                   2       Mariane
#
#      Sobrenome        Data            Loja  Preco Unitario  Unnamed: 8
# ...

# %%
# Passo 4 - Calcular o produto mais vendido (em quantidade)
tabela_produtos = tabela_total.groupby('Produto').sum()

# Selecionar a coluna "Quantidade Vendida" e ordenar os valores
tabela_produtos = tabela_produtos[["Quantidade Vendida"]].sort_values(by="Quantidade Vendida", ascending=False)

# Exibir o DataFrame agrupado por produto
display(tabela_produtos)
# Out:
#             Quantidade Vendida
# Produto
# iPhone                    8974
# Televisão                 5931
# Notebook                  3249
# Android                   3183
# SmartWatch                2980
# Tablet                    2921
# Câmera                    2805

# %%
# Passo 5 - Calcular o produto que mais faturou (em faturamento)
tabela_total['Faturamento'] = tabela_total['Quantidade Vendida'] * tabela_total['Preco Unitario']

tabela_faturamento = tabela_total.groupby('Produto').sum()
tabela_faturamento = tabela_faturamento[["Faturamento"]].sort_values(by="Faturamento", ascending=False)
display(tabela_faturamento)
# Out:
#             Faturamento
# Produto
# iPhone         47562200
# Televisão      14827500
# Notebook       11371500
# Android        10822200
# Câmera          5890500
# Tablet          4673600
# SmartWatch      4172000

# %%
# Passo 6 - Calcular a loja/cidade que mais vendeu (em faturamento) - criar um gráfico/dashboad
tabela_lojas = tabela_total.groupby('Loja').sum()
tabela_lojas = tabela_lojas[['Faturamento']]
display(tabela_lojas)
# Out:
#                 Faturamento
# Loja
# Belo Horizonte      6480300
# Curitiba            7060500
# Fortaleza          14087900
# Goiás               7441800
# Porto Alegre        6868600
# Recife              7303000
# Rio de Janeiro     14867800
# Salvador           13111300
# São Paulo          22098300

# %%
grafico = px.bar(tabela_lojas, x=tabela_lojas.index, y='Faturamento')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
